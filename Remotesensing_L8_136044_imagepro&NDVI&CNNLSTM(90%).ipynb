# %%
from osgeo import ogr, gdal, osr

# %%
pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.9/dist-packages (from seaborn) (3.5.3)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.9/dist-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.9/dist-packages (from seaborn) (1.22.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from seaborn) (1.10.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn) (23.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.23->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.15.0)

# %%
pip install parse
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: parse
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=d5d07ee0e97a6eba25aef0a4cab152ca41150f218fb281eeb02e11b8fa457d8d
#   Stored in directory: /root/.cache/pip/wheels/d6/9c/58/ee3ba36897e890f3ad81e9b730791a153fce20caa4a8a474df
# Successfully built parse
# Installing collected packages: parse
# Successfully installed parse-1.19.0

# %%
pip install rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasterio
#   Downloading rasterio-1.3.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 40.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from rasterio) (57.4.0)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from rasterio) (2022.12.7)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.9/dist-packages (from rasterio) (8.1.3)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/dist-packages (from rasterio) (22.2.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.9/dist-packages (from rasterio) (1.22.4)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.9/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Installing collected packages: snuggs, cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.3.6 snuggs-1.4.7

# %%
pip install scikit-image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (0.19.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (8.4.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (2023.2.28)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (23.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (1.22.4)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (2.9.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (3.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image) (1.4.1)

# %%
from rasterio import rasterio

# %%
import numpy as np
import os
import glob
import fnmatch
from PIL import Image
import os, os.path
from pylab import *
from parse import parse
import datetime
import pandas as pd
import skimage.transform as st
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, mean_squared_error, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.animation as animation
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras as keras
tf.random.set_seed(1234)
from tensorflow.keras.layers import LSTM

from tensorflow.keras.layers import  Dense, Dropout, Conv2D, MaxPool2D,TimeDistributed, Conv1D, MaxPooling1D, Flatten, Bidirectional,Input, Flatten, Activation, Reshape, RepeatVector, Concatenate
from tensorflow.keras.models import Model,Sequential
import keras.callbacks
from keras.callbacks import TensorBoard
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.layers import ConvLSTM2D

from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# To save raster
def saveRaster(dataset,datasetPath,cols,rows,projection,geotransform):
    rasterSet = gdal.GetDriverByName('GTiff').Create(datasetPath, cols, rows,1,gdal.GDT_Float32)
    rasterSet.SetProjection(projection)
    rasterSet.SetGeoTransform(geotransform)
    rasterSet.GetRasterBand(1).WriteArray(dataset)
    rasterSet.GetRasterBand(1).SetNoDataValue(-999)
    rasterSet = None

# %%
path_B5 = '/content/drive/MyDrive/L8_136044scene/LC08_L2SP_136044_20131217_20200912_02_T1_SR_B5.TIF'
B5 = gdal.Open(path_B5)
B5_Data = B5.GetRasterBand(1).ReadAsArray().astype(np.float32)
geotransform=B5.GetGeoTransform()
#print(geotransform)



fixedX1 = 279885
fixedX2 = 504315
fixedY1 = 2662515 
fixedY2 = 2452185 
originX,pixelWidth,empty,finalY,empty2,pixelHeight=geotransform
cols =  B5.RasterXSize
rows =  B5.RasterYSize        
projection = B5.GetProjection()
finalX = originX + pixelWidth * cols
originY = finalY + pixelHeight * rows

print(finalX,originY)
        
# Clipping the images to a common area
initialrow = int((finalY-fixedY1)/30)
finalrow = int(((finalY-originY)/30)-((fixedY2-originY)/30))
initialcol = int((fixedX1 - originX)/30)
finalcol = int(((finalX-originX)/30)-((finalX-fixedX2)/30))
B5_Data = B5_Data[initialrow: finalrow,initialcol : finalcol]        
print(initialrow,finalrow,initialcol,finalcol)
B5_Data1 = B5_Data[1000: 6000,1500 : 6000]

plt.imshow(B5_Data)
plt.colorbar()
# Out:
# 504615.0 2438985.0
# 350 7361 160 7641

# %%
B5_Data1 = B5_Data[780: 6200,1200 : 6550]
plt.imshow(B5_Data1)
plt.colorbar()

# %% [markdown]
# NDVI Prediction

# %%
#Convert Satellite Images into Arrays and Calculation of NDVI

#All images of 136044 Landsat 8 scene

imgs = []
path_B4=[]
path_B5=[]
path = "/content/drive/MyDrive/L8_136044scene"
df={}
i=0

# Commom GeoSpatial Coordinates of all images
fixedX1 = 279885
fixedX2 = 504315
fixedY1 = 2662515  
fixedY2 = 2452185  


for f in os.listdir(path):
     if fnmatch.fnmatch(f, '*LC08_L2SP_136044*') and fnmatch.fnmatch(f, '*B5*'):
        path_B5 = path + '/' +str(f)
        
        pattern = 'LC08_L2SP_136044_{Dates}_{otherstuff}.tif'
        result = parse(pattern, f)

        path_B4 = path +'/'+ f.replace("B5.TIF", "B4.TIF")  
    
        
        #Open raster bands
        B5 = gdal.Open(path_B5)
        B4 = gdal.Open(path_B4)
        #Read bands as matrix arrays
        B5_Data = B5.GetRasterBand(1).ReadAsArray().astype(np.float32)
        B4_Data = B4.GetRasterBand(1).ReadAsArray().astype(np.float32)
        # Geo Transformation of satellite image
        geotransform=B5.GetGeoTransform()
        # Calculate Final Geo Spatial Coordinates
        originX,pixelWidth,empty,finalY,empty2,pixelHeight=geotransform
        cols =  B5.RasterXSize
        rows =  B5.RasterYSize
        
        projection = B5.GetProjection()
        finalX = originX + pixelWidth * cols
        originY = finalY + pixelHeight * rows
        
        # Clipping the images to a common area
        initialrow = int((finalY-fixedY1)/30)
        finalrow = int(((finalY-originY)/30)-((fixedY2-originY)/30))
        initialcol = int((fixedX1 - originX)/30)
        finalcol = int(((finalX-originX)/30)-((finalX-fixedX2)/30))
        B5_Data = B5_Data[initialrow: finalrow,initialcol : finalcol]
        B4_Data = B4_Data[initialrow: finalrow,initialcol : finalcol] 

        # Removing area outside satellite image 
        B5_Data = B5_Data[1000: 6000,1500 : 6000]
        B4_Data = B4_Data[1000: 6000,1500 : 6000]
        
        # Resize array into 100*100 matrix
        new_rr_shape=(100,100)
        B4_Data = st.resize(B4_Data, new_rr_shape, mode='constant')
        B5_Data = st.resize(B5_Data, new_rr_shape, mode='constant')
        
        
        #Cakculation of NDVI
        ndvi = np.divide(B5_Data - B4_Data, B5_Data+ B4_Data,where=(B5_Data - B4_Data)!=0)
        ndvi[ndvi == 0] = -999
        df[result['Dates']] = ndvi

# Store the extracted and NDVI as .npz file      
outfileL8='/content/drive/MyDrive/outfileNDVI.npz'
np.savez(outfileL8, **df)

# %%
B4_Data
# Out:
# array([[ 6567.0938,  7582.0786,  7523.7617, ...,  6842.3364,  6963.946 ,
#          5906.4717],
#        [ 7543.1445,  8706.862 ,  8728.232 , ...,  8037.6396,  8057.833 ,
#          6924.5664],
#        [ 7321.3223,  8567.002 ,  8494.283 , ...,  7975.376 ,  8028.371 ,
#          6898.587 ],
#        ...,
#        [ 8928.396 , 10259.532 , 10282.278 , ...,  8016.8643,  7950.413 ,
#          6756.8623],
#        [ 9011.387 , 10351.173 , 10492.389 , ...,  8075.785 ,  8010.246 ,
#          6721.4526],
#        [ 8005.092 ,  9248.135 ,  9312.219 , ...,  6828.1836,  6745.1353,
#          5718.926 ]], dtype=float32)

# %%
B5_Data
# Out:
# array([[12673.089 , 15155.751 , 15197.714 , ..., 15798.816 , 17175.15  ,
#         13976.766 ],
#        [15225.214 , 17941.004 , 17779.14  , ..., 18849.852 , 19696.973 ,
#         16166.341 ],
#        [15562.779 , 18305.475 , 17916.062 , ..., 19000.516 , 19978.996 ,
#         15826.314 ],
#        ...,
#        [10523.4375, 12585.046 , 12351.596 , ..., 19750.527 , 20132.547 ,
#         17334.059 ],
#        [10153.822 , 12066.204 , 11669.818 , ..., 19930.203 , 20496.83  ,
#         17337.492 ],
#        [ 7748.032 ,  9224.129 ,  8463.996 , ..., 16923.367 , 16974.283 ,
#         14945.171 ]], dtype=float32)

# %%
x=np.load('/content/drive/MyDrive/outfileNDVI.npz')
print(x.files)
# Out:
# ['20170110', '20151223', '20180129', '20141204', '20131217', '20140219', '20170502', '20140102', '20190201', '20161022', '20151121', '20140424', '20200510', '20180302', '20150326', '20181129', '20201204', '20200204', '20170227', '20170211', '20141118', '20161225', '20171110', '20181231', '20200119', '20141220', '20191116', '20170126', '20151105']

# %%
print(len(x))
# Out:
# 29

# %%
# Read NDVI values stored in .npz file to a dataframe
def ReadNDVI(outfile, NDVIperImage):
  npzfile = np.load(outfile)
  for i in npzfile.files:
      date1 = datetime.datetime.strptime(i, "%Y%m%d").date()
      NDVIperImage = NDVIperImage.append({'Date': date1, 'NDVI': npzfile[i]}, ignore_index=True)
  return NDVIperImage

# %%
# Convert the NDVI change labels into categories
# 1 -- rock/Sand(less than 0.1), 2 --Grassland (.2 to .3), 3 --rainforest (0.6 to 0.8), 4-- others
def NDVI_Convert_to_Category(ndvi):
  ndviLabel = ndvi
  ndviLabel = np.where((ndviLabel <= 0.2),1,ndviLabel) #rocks
  ndviLabel = np.where((ndviLabel > 0.2) & (ndviLabel <= 0.6), 2, ndviLabel) #GrassLand
  ndviLabel = np.where((ndviLabel > 0.3) & (ndviLabel <= 0.6), 4, ndviLabel)
  ndviLabel = np.where((ndviLabel > 0.6) & (ndviLabel <= 1), 3, ndviLabel) #HighVegitation Mangr
  ndviLabel = np.where((ndviLabel > 0.8) & (ndviLabel < 1), 4, ndviLabel)
  ndviLabel = ndviLabel.astype(int)
  #print(ndviLabel[1])
  return ndviLabel

# %%
# Calculate NDVI change of adjacent satellite images
def CalculateNDVIChange(NDVIperImage):
  NDVIChangePerImage = {}
  for i in range(1,len(NDVIperImage)):
    DaysDifference = (NDVIperImage.loc[i].Date-NDVIperImage.loc[i-1].Date).days
    ndviChange = NDVIperImage.loc[i].NDVI-NDVIperImage.loc[i-1].NDVI
    ndviChange = np.where((NDVIperImage.loc[i-1].NDVI>-999) & (NDVIperImage.loc[i].NDVI>-999),ndviChange,-999)
    startDate = str(NDVIperImage.loc[i-1].Date)
    # NDVI Change Label
    ndviChangeLabel = NDVI_Convert_to_Category(ndviChange) 
    NDVIChangePerImage[str(NDVIperImage.loc[i].Date)] = [DaysDifference, ndviChange, ndviChangeLabel,startDate ]
  return NDVIChangePerImage

# %%
# NPZ file contain date and calculated NDVI
outfile='/content/drive/MyDrive/outfileNDVI.npz'

# Reading the date and NDVI into a dataframe
NDVIperImage = pd.DataFrame(columns=['Date', 'NDVI'])
NDVIperImage = ReadNDVI(outfile,NDVIperImage)

NDVIperImage = NDVIperImage.sort_values(by="Date" , ignore_index = True)
print(len(NDVIperImage))
# Out:
# 29

# %%
NDVI = CalculateNDVILabel(NDVIperImage)

print(len(NDVI))
# Out:
# 29

# %%
# Calculate NDVI Change
NDVIChangePerImage = CalculateNDVIChange(NDVIperImage)
print(len(NDVIChangePerImage.keys()))
#print(NDVIChangePerImage)
# Out:
# 28

# %%
for i in range(0, len(NDVIperImage)):
    img = NDVIperImage.NDVI[i]
    
    folder_path = "/content/images1/"
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    filename = "Landsat8_136044"+ '_' + str(NDVIperImage.Date[i]) +".jpg"
    print(filename)
    filepath = os.path.join(folder_path, filename)
    print(filepath)
    plt.imshow(img, cmap='RdYlGn')
    plt.title(filename)
    plt.savefig(filepath)
    plt.close()
# Out:
# Landsat8_136044_2013-12-17.jpg
# /content/images1/Landsat8_136044_2013-12-17.jpg
# Landsat8_136044_2014-01-02.jpg
# /content/images1/Landsat8_136044_2014-01-02.jpg
# Landsat8_136044_2014-02-19.jpg
# /content/images1/Landsat8_136044_2014-02-19.jpg
# Landsat8_136044_2014-04-24.jpg
# /content/images1/Landsat8_136044_2014-04-24.jpg
# Landsat8_136044_2014-11-18.jpg
# /content/images1/Landsat8_136044_2014-11-18.jpg
# Landsat8_136044_2014-12-04.jpg
# /content/images1/Landsat8_136044_2014-12-04.jpg
# Landsat8_136044_2014-12-20.jpg
# /content/images1/Landsat8_136044_2014-12-20.jpg
# Landsat8_136044_2015-03-26.jpg
# /content/images1/Landsat8_136044_2015-03-26.jpg
# Landsat8_136044_2015-11-05.jpg
# /content/images1/Landsat8_136044_2015-11-05.jpg
# Landsat8_136044_2015-11-21.jpg
# /content/images1/Landsat8_136044_2015-11-21.jpg
# Landsat8_136044_2015-12-23.jpg
# /content/images1/Landsat8_136044_2015-12-23.jpg
# Landsat8_136044_2016-10-22.jpg
# /content/images1/Landsat8_136044_2016-10-22.jpg
# Landsat8_136044_2016-12-25.jpg
# /content/images1/Landsat8_136044_2016-12-25.jpg
# Landsat8_136044_2017-01-10.jpg
# /content/images1/Landsat8_136044_2017-01-10.jpg
# Landsat8_136044_2017-01-26.jpg
# /content/images1/Landsat8_136044_2017-01-26.jpg
# Landsat8_136044_2017-02-11.jpg
# /content/images1/Landsat8_136044_2017-02-11.jpg
# Landsat8_136044_2017-02-27.jpg
# /content/images1/Landsat8_136044_2017-02-27.jpg
# Landsat8_136044_2017-05-02.jpg
# /content/images1/Landsat8_136044_2017-05-02.jpg
# Landsat8_136044_2017-11-10.jpg
# /content/images1/Landsat8_136044_2017-11-10.jpg
# Landsat8_136044_2018-01-29.jpg
# /content/images1/Landsat8_136044_2018-01-29.jpg
# Landsat8_136044_2018-03-02.jpg
# /content/images1/Landsat8_136044_2018-03-02.jpg
# Landsat8_136044_2018-11-29.jpg
# /content/images1/Landsat8_136044_2018-11-29.jpg
# Landsat8_136044_2018-12-31.jpg
# /content/images1/Landsat8_136044_2018-12-31.jpg
# Landsat8_136044_2019-02-01.jpg
# /content/images1/Landsat8_136044_2019-02-01.jpg
# Landsat8_136044_2019-11-16.jpg
# /content/images1/Landsat8_136044_2019-11-16.jpg
# Landsat8_136044_2020-01-19.jpg
# /content/images1/Landsat8_136044_2020-01-19.jpg
# Landsat8_136044_2020-02-04.jpg
# /content/images1/Landsat8_136044_2020-02-04.jpg
# Landsat8_136044_2020-05-10.jpg
# /content/images1/Landsat8_136044_2020-05-10.jpg
# Landsat8_136044_2020-12-04.jpg
# /content/images1/Landsat8_136044_2020-12-04.jpg

# %%
# !zip -r images1.zip /content/images1
# Out:
# updating: content/images1/ (stored 0%)
# updating: content/images1/Landsat8_136044_2018-11-29.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2020-02-04.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2017-02-27.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2014-04-24.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2017-02-11.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2017-11-10.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2015-12-23.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2020-01-19.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2013-12-17.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2018-01-29.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2020-05-10.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2017-05-02.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2014-11-18.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2018-12-31.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2014-01-02.jpg (deflated 7%)
# updating: content/images1/.png (deflated 1%)
# updating: content/images1/Landsat8_136044_2015-03-26.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2019-11-16.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2020-12-04.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2014-12-20.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2015-11-21.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2014-02-19.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2017-01-10.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2016-10-22.jpg (deflated 8%)
# updating: content/images1/Landsat8_136044_2014-12-04.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2019-02-01.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2017-01-26.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2018-03-02.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2016-12-25.jpg (deflated 7%)
# updating: content/images1/Landsat8_136044_2015-11-05.jpg (deflated 8%)

# %%
from google.colab import files
files.download('images1.zip')

# %%
# Plotting Calculted NDVI 
fig = plt.figure(figsize=(25, 40))
columns = 5
rows = 11
for i in range(0, len(NDVIperImage)):
    img = NDVIperImage.NDVI[i]
    
    folder_path = "/content/images/"
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    filename = "Landsat8_136044"+ '_' + str(NDVIperImage.Date[i]) +".jpg"
    filepath = os.path.join(folder_path, filename)
    plt.savefig(filepath)
   
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img, cmap='RdYlGn')
    plt.colorbar()
    plt.title('NDVI {}'.format(NDVIperImage.Date[i]))
plt.show()

# %%
#Plotting NDVI Change
fig = plt.figure(figsize=(25, 40))
columns = 5
rows = 11
j=1
for i in NDVIChangePerImage:
    title = str('--'.join([NDVIChangePerImage[i][3],i]))
    img = NDVIChangePerImage[i][1]
    fig.add_subplot(rows, columns, j)
    j = j+1
    plt.imshow(img, cmap='RdYlGn',vmin =-1, vmax =1)
    plt.colorbar()
    plt.title('NDVI Change{}'.format(title))
plt.show()

# %%
for i in NDVIChangePerImage:
    img = NDVIChangePerImage[i][1]
    
    folder_path = "/content/images_136044_change/"
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    filename = "Landsat8_136044"+ '_' + str('--'.join([NDVIChangePerImage[i][3],i])) +".jpg"
    print(filename)
    filepath = os.path.join(folder_path, filename)
    print(filepath)
    plt.imshow(img, cmap='RdYlGn')
    plt.title(filename)
    plt.savefig(filepath)
    plt.close()
# Out:
# Landsat8_136044_2013-12-17--2014-01-02.jpg
# /content/images_136044_change/Landsat8_136044_2013-12-17--2014-01-02.jpg
# Landsat8_136044_2014-01-02--2014-02-19.jpg
# /content/images_136044_change/Landsat8_136044_2014-01-02--2014-02-19.jpg
# Landsat8_136044_2014-02-19--2014-04-24.jpg
# /content/images_136044_change/Landsat8_136044_2014-02-19--2014-04-24.jpg
# Landsat8_136044_2014-04-24--2014-11-18.jpg
# /content/images_136044_change/Landsat8_136044_2014-04-24--2014-11-18.jpg
# Landsat8_136044_2014-11-18--2014-12-04.jpg
# /content/images_136044_change/Landsat8_136044_2014-11-18--2014-12-04.jpg
# Landsat8_136044_2014-12-04--2014-12-20.jpg
# /content/images_136044_change/Landsat8_136044_2014-12-04--2014-12-20.jpg
# Landsat8_136044_2014-12-20--2015-03-26.jpg
# /content/images_136044_change/Landsat8_136044_2014-12-20--2015-03-26.jpg
# Landsat8_136044_2015-03-26--2015-11-05.jpg
# /content/images_136044_change/Landsat8_136044_2015-03-26--2015-11-05.jpg
# Landsat8_136044_2015-11-05--2015-11-21.jpg
# /content/images_136044_change/Landsat8_136044_2015-11-05--2015-11-21.jpg
# Landsat8_136044_2015-11-21--2015-12-23.jpg
# /content/images_136044_change/Landsat8_136044_2015-11-21--2015-12-23.jpg
# Landsat8_136044_2015-12-23--2016-10-22.jpg
# /content/images_136044_change/Landsat8_136044_2015-12-23--2016-10-22.jpg
# Landsat8_136044_2016-10-22--2016-12-25.jpg
# /content/images_136044_change/Landsat8_136044_2016-10-22--2016-12-25.jpg
# Landsat8_136044_2016-12-25--2017-01-10.jpg
# /content/images_136044_change/Landsat8_136044_2016-12-25--2017-01-10.jpg
# Landsat8_136044_2017-01-10--2017-01-26.jpg
# /content/images_136044_change/Landsat8_136044_2017-01-10--2017-01-26.jpg
# Landsat8_136044_2017-01-26--2017-02-11.jpg
# /content/images_136044_change/Landsat8_136044_2017-01-26--2017-02-11.jpg
# Landsat8_136044_2017-02-11--2017-02-27.jpg
# /content/images_136044_change/Landsat8_136044_2017-02-11--2017-02-27.jpg
# Landsat8_136044_2017-02-27--2017-05-02.jpg
# /content/images_136044_change/Landsat8_136044_2017-02-27--2017-05-02.jpg
# Landsat8_136044_2017-05-02--2017-11-10.jpg
# /content/images_136044_change/Landsat8_136044_2017-05-02--2017-11-10.jpg
# Landsat8_136044_2017-11-10--2018-01-29.jpg
# /content/images_136044_change/Landsat8_136044_2017-11-10--2018-01-29.jpg
# Landsat8_136044_2018-01-29--2018-03-02.jpg
# /content/images_136044_change/Landsat8_136044_2018-01-29--2018-03-02.jpg
# Landsat8_136044_2018-03-02--2018-11-29.jpg
# /content/images_136044_change/Landsat8_136044_2018-03-02--2018-11-29.jpg
# Landsat8_136044_2018-11-29--2018-12-31.jpg
# /content/images_136044_change/Landsat8_136044_2018-11-29--2018-12-31.jpg
# Landsat8_136044_2018-12-31--2019-02-01.jpg
# /content/images_136044_change/Landsat8_136044_2018-12-31--2019-02-01.jpg
# Landsat8_136044_2019-02-01--2019-11-16.jpg
# /content/images_136044_change/Landsat8_136044_2019-02-01--2019-11-16.jpg
# Landsat8_136044_2019-11-16--2020-01-19.jpg
# /content/images_136044_change/Landsat8_136044_2019-11-16--2020-01-19.jpg
# Landsat8_136044_2020-01-19--2020-02-04.jpg
# /content/images_136044_change/Landsat8_136044_2020-01-19--2020-02-04.jpg
# Landsat8_136044_2020-02-04--2020-05-10.jpg
# /content/images_136044_change/Landsat8_136044_2020-02-04--2020-05-10.jpg
# Landsat8_136044_2020-05-10--2020-12-04.jpg
# /content/images_136044_change/Landsat8_136044_2020-05-10--2020-12-04.jpg

# %%
# Create arrays of NDVI change and NDVI change label
x = []
y = []

for ndvi,label in NDVI.values():
    x.append(ndvi)
    y.append(label)

# %%
# Create x_train, y_train x_test and y_test
x_train = x[0:13]
y_train = x[1:14]
x_crossval = x[13:20]
y_crossval = x[14:21]
x_test = x[20:28]
y_test = x[21:29]
x_train = np.array(x_train)
y_train = np.array(y_train)
x_crossval = np.array(x_crossval)
y_crossval = np.array(y_crossval)
x_test = np.array(x_test)
y_test = np.array(y_test)
x_test_label = y[20:28]
y_test_label = y[21:29]
x_test_label = np.array(x_test_label)
y_test_label = np.array(y_test_label)

print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (13, 100, 100)
# (8, 100, 100)
# (8, 100, 100)
# (13, 100, 100)

# %%
from tensorflow.keras import layers
def build_model():
    model = Sequential()

    #model.add(LSTM(400, batch_input_shape=(1, 100, 100), stateful=True, return_sequences=True))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same', input_shape=(100,100)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Flatten())
    model.add(RepeatVector(100))
    model.add(Dropout(0.05))
    
    model.add(LSTM(200, return_sequences=True))
    model.add(LSTM(100, return_sequences=True))
    #model.add(TimeDistributed(Dense(100)))

    model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae','accuracy'])
    return model

# %%
#Defining the model
model = build_model()
print(model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_15 (Conv1D)          (None, 100, 128)          38528
#
#  max_pooling1d_15 (MaxPoolin  (None, 50, 128)          0
#  g1D)
#
#  conv1d_16 (Conv1D)          (None, 50, 64)            24640
#
#  max_pooling1d_16 (MaxPoolin  (None, 25, 64)           0
#  g1D)
#
#  conv1d_17 (Conv1D)          (None, 25, 32)            6176
#
#  max_pooling1d_17 (MaxPoolin  (None, 12, 32)           0
#  g1D)
#
#  flatten_7 (Flatten)         (None, 384)               0
#
#  repeat_vector_7 (RepeatVect  (None, 100, 384)         0
#  or)
#
#  dropout_7 (Dropout)         (None, 100, 384)          0
#
#  lstm_20 (LSTM)              (None, 100, 200)          468000
#
#  lstm_21 (LSTM)              (None, 100, 100)          120400
#
# =================================================================
# Total params: 657,744
# Trainable params: 657,744
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
import time
start = time.time()

history = model.fit(x_train, y_train, validation_data=(x_test,y_test), epochs=40,batch_size=1,
                    verbose=1, shuffle =False)

stop = time.time()
print(f"Training time: {stop - start} seconds")

print(len(history.history['loss']))
# Out:
# Epoch 1/40
# 13/13 [==============================] - 9s 363ms/step - loss: 0.0293 - mse: 0.0293 - mae: 0.1351 - accuracy: 0.0269 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0803 - val_accuracy: 0.0338
# Epoch 2/40
# 13/13 [==============================] - 2s 193ms/step - loss: 0.0127 - mse: 0.0127 - mae: 0.0889 - accuracy: 0.0292 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0711 - val_accuracy: 0.0338
# Epoch 3/40
# 13/13 [==============================] - 3s 258ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0798 - accuracy: 0.0469 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0661 - val_accuracy: 0.1013
# Epoch 4/40
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0771 - accuracy: 0.0554 - val_loss: 0.0087 - val_mse: 0.0087 - val_mae: 0.0649 - val_accuracy: 0.0362
# Epoch 5/40
# 13/13 [==============================] - 3s 249ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0760 - accuracy: 0.0400 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0640 - val_accuracy: 0.0988
# Epoch 6/40
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0099 - mse: 0.0099 - mae: 0.0755 - accuracy: 0.0515 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0636 - val_accuracy: 0.0712
# Epoch 7/40
# 13/13 [==============================] - 2s 165ms/step - loss: 0.0098 - mse: 0.0098 - mae: 0.0753 - accuracy: 0.0431 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0633 - val_accuracy: 0.0862
# Epoch 8/40
# 13/13 [==============================] - 2s 173ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0749 - accuracy: 0.0608 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0630 - val_accuracy: 0.0613
# Epoch 9/40
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0747 - accuracy: 0.0469 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0627 - val_accuracy: 0.0175
# Epoch 10/40
# 13/13 [==============================] - 3s 241ms/step - loss: 0.0096 - mse: 0.0096 - mae: 0.0743 - accuracy: 0.0377 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0625 - val_accuracy: 0.0088
# Epoch 11/40
# 13/13 [==============================] - 3s 195ms/step - loss: 0.0095 - mse: 0.0095 - mae: 0.0741 - accuracy: 0.0338 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0623 - val_accuracy: 0.0262
# Epoch 12/40
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0095 - mse: 0.0095 - mae: 0.0740 - accuracy: 0.0338 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0621 - val_accuracy: 0.0262
# Epoch 13/40
# 13/13 [==============================] - 2s 173ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0735 - accuracy: 0.0308 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0617 - val_accuracy: 0.0100
# Epoch 14/40
# 13/13 [==============================] - 2s 175ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0734 - accuracy: 0.0262 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0616 - val_accuracy: 0.0125
# Epoch 15/40
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0732 - accuracy: 0.0300 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0613 - val_accuracy: 0.0288
# Epoch 16/40
# 13/13 [==============================] - 3s 264ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0729 - accuracy: 0.0292 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0609 - val_accuracy: 0.0338
# Epoch 17/40
# 13/13 [==============================] - 2s 172ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0726 - accuracy: 0.0392 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0605 - val_accuracy: 0.0312
# Epoch 18/40
# 13/13 [==============================] - 2s 173ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0723 - accuracy: 0.0431 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0602 - val_accuracy: 0.0300
# Epoch 19/40
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0090 - mse: 0.0090 - mae: 0.0722 - accuracy: 0.0354 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0598 - val_accuracy: 0.0162
# Epoch 20/40
# 13/13 [==============================] - 2s 172ms/step - loss: 0.0090 - mse: 0.0090 - mae: 0.0720 - accuracy: 0.0392 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0595 - val_accuracy: 0.0113
# Epoch 21/40
# 13/13 [==============================] - 3s 271ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0716 - accuracy: 0.0423 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0592 - val_accuracy: 0.0200
# Epoch 22/40
# 13/13 [==============================] - 2s 186ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0712 - accuracy: 0.0508 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0589 - val_accuracy: 0.0225
# Epoch 23/40
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0714 - accuracy: 0.0462 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0586 - val_accuracy: 0.0213
# Epoch 24/40
# 13/13 [==============================] - 3s 251ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0708 - accuracy: 0.0569 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0584 - val_accuracy: 0.0375
# Epoch 25/40
# 13/13 [==============================] - 2s 164ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0708 - accuracy: 0.0577 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0582 - val_accuracy: 0.0300
# Epoch 26/40
# 13/13 [==============================] - 3s 274ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0705 - accuracy: 0.0646 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0580 - val_accuracy: 0.0375
# Epoch 27/40
# 13/13 [==============================] - 2s 172ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0705 - accuracy: 0.0654 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0580 - val_accuracy: 0.0362
# Epoch 28/40
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0703 - accuracy: 0.0677 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0578 - val_accuracy: 0.0375
# Epoch 29/40
# 13/13 [==============================] - 2s 175ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0700 - accuracy: 0.0623 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0575 - val_accuracy: 0.0338
# Epoch 30/40
# 13/13 [==============================] - 2s 174ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0702 - accuracy: 0.0669 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0576 - val_accuracy: 0.0275
# Epoch 31/40
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0696 - accuracy: 0.0769 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0573 - val_accuracy: 0.0487
# Epoch 32/40
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0693 - accuracy: 0.0738 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0570 - val_accuracy: 0.0400
# Epoch 33/40
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0693 - accuracy: 0.0715 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0569 - val_accuracy: 0.0450
# Epoch 34/40
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0697 - accuracy: 0.0708 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0573 - val_accuracy: 0.0437
# Epoch 35/40
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0695 - accuracy: 0.0692 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0567 - val_accuracy: 0.0413
# Epoch 36/40
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0691 - accuracy: 0.0754 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0567 - val_accuracy: 0.0562
# Epoch 37/40
# 13/13 [==============================] - 3s 260ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0685 - accuracy: 0.0808 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0564 - val_accuracy: 0.0425
# Epoch 38/40
# 13/13 [==============================] - 2s 181ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0685 - accuracy: 0.0723 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0565 - val_accuracy: 0.0887
# Epoch 39/40
# 13/13 [==============================] - 2s 164ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0689 - accuracy: 0.0754 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0567 - val_accuracy: 0.0437
# Epoch 40/40
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0687 - accuracy: 0.0785 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0564 - val_accuracy: 0.0388
# Training time: 145.92770552635193 seconds
# 40

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
pred_train = model.predict(x_train, batch_size=1)
pred_test = model.predict(x_test, batch_size=1)
#print(pred_test.shape)
pred_test_label = NDVI_Convert_to_Category(pred_test)
print(pred_test_label.shape)
pred_test_label = pred_test_label.reshape(pred_test_label.shape[0]*10000)
#print(pred_test_label.shape)
y_test_label = y_test_label.reshape(y_test_label.shape[0]*10000)
print(y_test_label.shape)
# Out:
# 13/13 [==============================] - 1s 25ms/step
# 8/8 [==============================] - 0s 26ms/step
# (8, 100, 100)
# (80000,)

# %%
print(y_test_label.shape, pred_test_label.shape) 
#print(y_test_label, pred_test_label)
accuracy = accuracy_score(y_test_label, pred_test_label)
#print("Accuracy: ", accuracy)
precision = precision_score(y_test_label, pred_test_label, average='weighted')
f1 = f1_score(y_test_label, pred_test_label, average='weighted')
recall = recall_score(y_test_label, pred_test_label, average='weighted')
#Loss = history.history['loss'][4]
#print(history.history['loss'])
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("F1 Score", f1)
print("Recall:", recall)
report = classification_report(y_test_label, pred_test_label)
print(report)
# Out:
# (80000,) (80000,)
# Accuracy:  0.895875
# Precision:  0.8924669177379195
# F1 Score 0.8526287502185125
# Recall: 0.895875
#               precision    recall  f1-score   support
#
#            2       0.90      1.00      0.94     71284
#            3       0.86      0.05      0.10      8716
#
#     accuracy                           0.90     80000
#    macro avg       0.88      0.53      0.52     80000
# weighted avg       0.89      0.90      0.85     80000
